# %%
from graph.workflow import analyst_bot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from graph.workflow import analyst_bot
#
# ImportError: cannot import name 'analyst_bot' from 'graph.workflow' (/mnt/e/AI Data Analyst/graph/workflow.py)

# %%
analyst_bot.invoke("")
